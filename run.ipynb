# %% [markdown]
# ## Import libraries

# %%
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="2"

import monai
from monai.data import ArrayDataset, DataLoader
from monai.transforms import Compose, LoadImaged, EnsureChannelFirstd, Orientationd, Spacingd, CropForegroundd, ScaleIntensityRangePercentilesd, Resized

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# reload if update
import importlib
import util
importlib.reload(util)
# Out:
# <module 'util' from '/home/xavier/IMA206_project/util.py'>

# %%
# Set the random seed
seed = 123
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Load data and visualize

# %%
# visualize raw example before preprocessing
data_dict1 = util.load_data_dict(1,'ED')
util.visualize_3D(data_dict1)

# %%
train_dicts = []
for patient_id in range(1,101):
    train_dicts.append(util.load_file_dict(patient_id,'ED'))
    train_dicts.append(util.load_file_dict(patient_id,'ES'))

test_dicts = []
for patient_id in range(101,151):
    test_dicts.append(util.load_file_dict(patient_id,'ED'))
    test_dicts.append(util.load_file_dict(patient_id,'ES'))

len(train_dicts), len(test_dicts), train_dicts[0]
# Out:
# (200,
#  100,
#  {'image': './database/training/patient001/patient001_frame01.nii.gz',
#   'label': './database/training/patient001/patient001_frame01_gt.nii.gz'})

# %% [markdown]
# ## Preprocessing

# %%
class CropForegroundSquared:
    '''
    crop input using bounding box with flex margin such that output is square
    '''
    def __init__(self, keys, source_key, min_margin):
        self.keys = keys
        self.source_key = source_key
        self.min_margin = min_margin

    def __call__(self, img_dict):
        mask = img_dict[self.source_key] > 0
        idx = torch.argwhere(mask)
        mins,_ = idx.min(dim=0)
        maxs,_ = idx.max(dim=0)
        _, a, b, _ = maxs - mins
        z_s = mins[3]
        z_e = maxs[3]+1
        if a >= b:
            off = (a-b)//2
            x_s = mins[1]-self.min_margin
            x_e = maxs[1]+self.min_margin+1
            y_s = mins[2]-self.min_margin-off
            y_e = maxs[2]+self.min_margin+off+1
        else:
            off = (b-a)//2
            x_s = mins[1]-self.min_margin-off
            x_e = maxs[1]+self.min_margin+off+1
            y_s = mins[2]-self.min_margin
            y_e = maxs[2]+self.min_margin+1
        for k in self.keys:
            img_dict[k] = img_dict[k][:,x_s:x_e,y_s:y_e,z_s:z_e]
        return img_dict


class To2DSlice:
    '''
    permute depth dimension to first channel
    return [image, label] of dimension (D,1,H,W)
    '''
    def __init__(self, keys):
        self.keys = keys

    def __call__(self, img_dict):
        ret = []
        for k in self.keys:
            ret.append(img_dict[k].permute(3,0,1,2))
        return ret

# %%
transforms_2d = Compose(
    [LoadImaged(keys=["image", "label"], image_only=False),
     EnsureChannelFirstd(keys=["image", "label"]),
     Orientationd(keys=["image", "label"], axcodes="RAS"),
     Spacingd(
        keys=["image", "label"],
        pixdim=[1.25, 1.25, 10],
        mode=("bilinear", "nearest")),
     CropForegroundSquared(keys=["image", "label"], source_key="label", min_margin=5),
     ScaleIntensityRangePercentilesd(
        keys=["image"],
        lower=5,
        upper=95,
        b_min=0.0,
        b_max=1.0,
        clip=True),
     Resized(
        keys=["image", "label"],
        spatial_size=(128,128,-1),
        mode=("trilinear", "nearest")),
     To2DSlice(keys=["image", "label"])])


train_data = []
for train_dict in tqdm(train_dicts, desc='preprocess train set'):
    train_data.append(transforms_2d(train_dict))

test_data = []
for test_dict in tqdm(test_dicts, desc='preprocess test set'):
    test_data.append(transforms_2d(test_dict))

train_X, train_Y = zip(*train_data)
test_X, test_Y = zip(*test_data)
train_X = torch.concatenate(train_X, dim=0)
train_Y = torch.concatenate(train_Y, dim=0)
test_X = torch.concatenate(test_X, dim=0)
test_Y = torch.concatenate(test_Y, dim=0)

train_X.shape, test_X.shape
# Out:
# preprocess train set: 100%|███████████████████| 200/200 [00:27<00:00,  7.37it/s]
# preprocess test set: 100%|████████████████████| 100/100 [00:13<00:00,  7.18it/s]
# (torch.Size([1665, 1, 128, 128]), torch.Size([857, 1, 128, 128]))

# %%
# visualize example after preprocessing
util.visualize_3D({"image": train_X[:9,0].permute(1,2,0),
                   "label": train_Y[:9,0].permute(1,2,0)})

# %%
t = Compose(
    [LoadImaged(keys=["image", "label"], image_only=False),
     EnsureChannelFirstd(keys=["image", "label"]),
     Orientationd(keys=["image", "label"], axcodes="RAS"),
     Spacingd(
        keys=["image", "label"],
        pixdim=[1.25, 1.25, 10],
        mode=("bilinear", "nearest"))])
img = t(train_dicts[4])['image'][..., 4]
mask = t(train_dicts[4])['label'][..., 4]

idx = torch.argwhere(mask)
mins,_ = idx.min(dim=0)
maxs,_ = idx.max(dim=0)
_, a, b = maxs - mins
if a >= b:
    off = (a-b)//2
    x_s = mins[1]-5
    x_e = maxs[1]+5+1
    y_s = mins[2]-5-off
    y_e = maxs[2]+5+off
else:
    off = (b-a)//2
    x_s = mins[1]-5-off
    x_e = maxs[1]+5+off
    y_s = mins[2]-5
    y_e = maxs[2]+5+1

# %%
fig, ax = plt.subplots(figsize=(10,10))
util.visualize_2D({"image": img,
                   "label": mask}, ax_=ax)

ax.plot([y_s, y_s],[x_s, x_e], c='w', label='Custom version, bbox adjusted to square')
ax.plot([y_e, y_e],[x_s, x_e], c='w')
ax.plot([y_s, y_e],[x_s, x_s], c='w')
ax.plot([y_s, y_e],[x_e, x_e], c='w')

ax.plot([y_s+off, y_s+off],[x_s, x_e], c='y', label='Original version, bbox rectangle')
ax.plot([y_e-off, y_e-off],[x_s, x_e], c='y')
ax.plot([y_s+off, y_e-off],[x_s, x_s], c='y')
ax.plot([y_s+off, y_e-off],[x_e, x_e], c='y')

plt.legend()
# plt.savefig('images/comp_crop.png')

# %%
from monai.transforms import ScaleIntensityRangePercentiles

# %%
plt.hist(img.reshape(-1), bins=100)
plt.plot(np.percentile(img.reshape(-1), [5, 95]), [5000, 5000], '--', label='Range of 5% to 95% percentile')
plt.xlabel('Intensity')
plt.ylim(0, 10000)
plt.legend()

# %%
s = ScaleIntensityRangePercentiles(
        lower=5,
        upper=95,
        b_min=0.0,
        b_max=1.0,
        clip=True)
plt.hist(s(img).reshape(-1), bins=100)
plt.xlabel('Scaled Intensity')
# Out:
# Text(0.5, 0, 'Scaled Intensity')

# %% [markdown]
# ## Prepare dataset and dataloader and data augmentation

# %%
from sklearn.model_selection import train_test_split
from monai.transforms import RandFlip, RandRotate, RandAdjustContrast, RandZoom

# %%
TRAIN_RATIO = 0.7
BATCH_SIZE = 64
BATCH_SIZE_VAL = 64
PROB = 0.3

# %%
# split train and validation
train_X, val_X, train_Y, val_Y = train_test_split(train_X, train_Y, train_size=TRAIN_RATIO)

# %%
# data augmentation
data_aug_img = Compose([
    RandFlip(
        spatial_axis=[0],
        prob=PROB),
    RandFlip(
        spatial_axis=[1],
        prob=PROB),

    RandRotate(
        range_x=0.25*np.pi, # [-45,45]
        prob=PROB),

    RandZoom(
        min_zoom=0.8, max_zoom=1.2,
        prob=PROB,
    ),
    RandAdjustContrast( # Randomly changes image intensity by gamma
        # x = ((x - min) / intensity_range) ^ gamma * intensity_range + min
        prob=PROB)])

data_aug_seg = Compose([
    RandFlip(
        spatial_axis=[0],
        prob=PROB),
    RandFlip(
        spatial_axis=[1],
        prob=PROB),

    RandRotate(
        range_x=0.25*np.pi, # [-45,45]
        prob=PROB),

    RandZoom(
        min_zoom=0.8, max_zoom=1.2,
        prob=PROB)])

train_set = ArrayDataset(img=train_X, seg=train_Y, img_transform=data_aug_img, seg_transform=data_aug_seg)
train_set_wo_da = ArrayDataset(img=train_X, seg=train_Y) # without data augmentation

val_set = ArrayDataset(img=val_X, seg=val_Y)
test_set = ArrayDataset(img=test_X, seg=test_Y)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
train_loader_wo_da = DataLoader(train_set_wo_da, batch_size=BATCH_SIZE, shuffle=True) # without data augmentation

val_loader = DataLoader(val_set, batch_size=BATCH_SIZE_VAL)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE_VAL)

# %%
# Visualize the effect of the data augmentation
batch = next(iter(train_loader))
# batch['image'].shape, batch['label'].shape
util.visualize_3D({'image': batch[0][:10, 0].permute(1,2,0), 
                   'label': batch[1][:10, 0].permute(1,2,0)})

# %% [markdown]
# ## Train a U-Net

# %%
from unet import UNet

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LR = 1e-2
EPOCH = 150
SAVE_UNET_PATH = 'saved_models/tmp.pt'
if not os.path.exists('saved_models'):
    os.makedirs('saved_models')

# %%
def compute_eval_loss(model, val_loader, loss_function):
    epoch_val_loss = 0
    with torch.no_grad():
        for batch_data in val_loader:
            inputs = batch_data[0]
            labels = batch_data[1]

            outputs = model(inputs.to(DEVICE))
            loss = loss_function(outputs, labels.to(DEVICE))

            # print(loss.item())
            epoch_val_loss += loss.item()

    return epoch_val_loss / len(val_loader)


def train(model, train_loader, val_loader, test_loader, save_path):
    # train model
    model.train()

    # Compute both Dice loss and Cross Entropy Loss, and return the weighted sum of these two losses
    loss_function = monai.losses.DiceCELoss(softmax=True, to_onehot_y=True,
                                            lambda_dice=1, lambda_ce=0.1)

    optimizer = torch.optim.Adam(model.parameters(), lr=LR)

    training_losses = []
    val_losses = []

    min_val_loss = np.inf
    best_epoch = 0

    for epoch in range(EPOCH):
        epoch_loss = 0

        for batch_data in train_loader:
            inputs = batch_data[0].to(DEVICE)
            labels = batch_data[1].to(DEVICE)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = loss_function(outputs, labels)
            loss.backward()

            optimizer.step()

            epoch_loss += loss.item()

        training_loss = epoch_loss / len(train_loader)
        training_losses.append(training_loss)

        # compute loss on validation set
        val_loss = compute_eval_loss(model, val_loader, loss_function)
        val_losses.append(val_loss)

        print(f'\nepoch {epoch}/{EPOCH} training loss: {training_loss} validation loss: {val_loss}')

        # if minimum validation loss, save model
        if val_loss < min_val_loss:
            torch.save(model.state_dict(), save_path)
            print('New minimum validation loss')
            min_val_loss = val_loss
            best_epoch = epoch
        else:
            print('No improvement on validation loss')


    model.load_state_dict(torch.load(save_path))
    print(f'Best validation error {min_val_loss:.4f} is achieved at epoch {best_epoch}')

    test_loss = compute_eval_loss(model, test_loader, loss_function)
    print(f'Test loss {test_loss:.4f}.')


    return {
        "training_losses": training_losses,
        "val_losses": val_losses,
        "best_epoch": best_epoch,
    }

# %%
# define model, loss function and optimizer
model = UNet(n_channels=1, n_classes=4).to(DEVICE)

ret_dict = train(model, train_loader, val_loader, test_loader, 'saved_models/w_da.pt')
# Out:
# epoch 0/150 training loss: 0.6547260409907291 validation loss: 0.4567990265786648
# New minimum validation loss
#
# epoch 1/150 training loss: 0.4938311247449172 validation loss: 0.39993834868073463
# New minimum validation loss
#
# epoch 2/150 training loss: 0.44806745491529765 validation loss: 0.37522822991013527
# New minimum validation loss
#
# epoch 3/150 training loss: 0.4120890090340062 validation loss: 0.3684824965894222
# New minimum validation loss
#
# epoch 4/150 training loss: 0.3916013711377194 validation loss: 0.3210366815328598
# New minimum validation loss
#
# epoch 5/150 training loss: 0.36361661710237203 validation loss: 0.3005497306585312
# New minimum validation loss
#
# epoch 6/150 training loss: 0.34383558599572434 validation loss: 0.2750631086528301
# New minimum validation loss
#
# epoch 7/150 training loss: 0.3290441349933022 validation loss: 0.27817881293594837
# No improvement on validation loss
#
# epoch 8/150 training loss: 0.30383399991612686 validation loss: 0.24899139814078808
# New minimum validation loss
#
# epoch 9/150 training loss: 0.29965814477518987 validation loss: 0.238948130980134
# New minimum validation loss
#
# epoch 10/150 training loss: 0.29264228751784876 validation loss: 0.2340825069695711
# New minimum validation loss
#
# epoch 11/150 training loss: 0.27396729745362935 validation loss: 0.23318819515407085
# New minimum validation loss
#
# epoch 12/150 training loss: 0.26374413229917226 validation loss: 0.2108715884387493
# New minimum validation loss
#
# epoch 13/150 training loss: 0.25230910825101954 validation loss: 0.2111609447747469
# No improvement on validation loss
#
# epoch 14/150 training loss: 0.24540950906904122 validation loss: 0.20136108063161373
# New minimum validation loss
#
# epoch 15/150 training loss: 0.2325629411559356 validation loss: 0.19800610840320587
# New minimum validation loss
#
# epoch 16/150 training loss: 0.23184160888195038 validation loss: 0.1992209367454052
# No improvement on validation loss
#
# epoch 17/150 training loss: 0.22977854311466217 validation loss: 0.19426674209535122
# New minimum validation loss
#
# epoch 18/150 training loss: 0.22114811367110201 validation loss: 0.2040504366159439
# No improvement on validation loss
#
# epoch 19/150 training loss: 0.22018403599136754 validation loss: 0.18466885946691036
# New minimum validation loss
#
# epoch 20/150 training loss: 0.2089851726042597 validation loss: 0.18004834093153477
# New minimum validation loss
#
# epoch 21/150 training loss: 0.20808583811709755 validation loss: 0.19340299628674984
# No improvement on validation loss
#
# epoch 22/150 training loss: 0.2156482707513006 validation loss: 0.19039257243275642
# No improvement on validation loss
#
# epoch 23/150 training loss: 0.20799600999606283 validation loss: 0.18030688911676407
# No improvement on validation loss
#
# epoch 24/150 training loss: 0.20425747727092944 validation loss: 0.1830496285110712
# No improvement on validation loss
#
# epoch 25/150 training loss: 0.20546634416831167 validation loss: 0.17739582620561123
# New minimum validation loss
#
# epoch 26/150 training loss: 0.19605458410162674 validation loss: 0.17508233711123466
# New minimum validation loss
#
# epoch 27/150 training loss: 0.19386515884022965 validation loss: 0.17198128439486027
# New minimum validation loss
#
# epoch 28/150 training loss: 0.19194433720488296 validation loss: 0.18889711052179337
# No improvement on validation loss
#
# epoch 29/150 training loss: 0.19656954784142344 validation loss: 0.16879690997302532
# New minimum validation loss
#
# epoch 30/150 training loss: 0.19771173674809306 validation loss: 0.18749027885496616
# No improvement on validation loss
#
# epoch 31/150 training loss: 0.20122233895879044 validation loss: 0.1753497589379549
# No improvement on validation loss
#
# epoch 32/150 training loss: 0.19729483127593994 validation loss: 0.17850812897086143
# No improvement on validation loss
#
# epoch 33/150 training loss: 0.1950379429679168 validation loss: 0.17487476766109467
# No improvement on validation loss
#
# epoch 34/150 training loss: 0.19244523816987089 validation loss: 0.16444394923746586
# New minimum validation loss
#
# epoch 35/150 training loss: 0.18900379460108907 validation loss: 0.172807851806283
# No improvement on validation loss
#
# epoch 36/150 training loss: 0.1825815376482512 validation loss: 0.17201418988406658
# No improvement on validation loss
#
# epoch 37/150 training loss: 0.1857885922256269 validation loss: 0.1634418610483408
# New minimum validation loss
#
# epoch 38/150 training loss: 0.1839147774796737 validation loss: 0.16546140424907207
# No improvement on validation loss
#
# epoch 39/150 training loss: 0.18308931196990766 validation loss: 0.16480477899312973
# No improvement on validation loss
#
# epoch 40/150 training loss: 0.17973041534423828 validation loss: 0.1663399636745453
# No improvement on validation loss
#
# epoch 41/150 training loss: 0.17789242926396823 validation loss: 0.16633874364197254
# No improvement on validation loss
#
# epoch 42/150 training loss: 0.1759448129879801 validation loss: 0.16397975012660027
# No improvement on validation loss
#
# epoch 43/150 training loss: 0.17460560171227707 validation loss: 0.16798912174999714
# No improvement on validation loss
#
# epoch 44/150 training loss: 0.17508850913298757 validation loss: 0.16643895581364632
# No improvement on validation loss
#
# epoch 45/150 training loss: 0.17681593173428586 validation loss: 0.16136977449059486
# New minimum validation loss
#
# epoch 46/150 training loss: 0.17356807228765989 validation loss: 0.16255406104028225
# No improvement on validation loss
#
# epoch 47/150 training loss: 0.1747606773125498 validation loss: 0.15958509594202042
# New minimum validation loss
#
# epoch 48/150 training loss: 0.1748386590104354 validation loss: 0.16079137846827507
# No improvement on validation loss
#
# epoch 49/150 training loss: 0.17050495508470034 validation loss: 0.16388902440667152
# No improvement on validation loss
#
# epoch 50/150 training loss: 0.1760341642718566 validation loss: 0.1561862900853157
# New minimum validation loss
#
# epoch 51/150 training loss: 0.16842801398352572 validation loss: 0.15744668617844582
# No improvement on validation loss
#
# epoch 52/150 training loss: 0.16890465350527512 validation loss: 0.1582049746066332
# No improvement on validation loss
#
# epoch 53/150 training loss: 0.16839195395770826 validation loss: 0.16081789880990982
# No improvement on validation loss
#
# epoch 54/150 training loss: 0.16717231352078288 validation loss: 0.15614252910017967
# New minimum validation loss
#
# epoch 55/150 training loss: 0.16672261921983017 validation loss: 0.15475112572312355
# New minimum validation loss
#
# epoch 56/150 training loss: 0.16745957183210472 validation loss: 0.15734709799289703
# No improvement on validation loss
#
# epoch 57/150 training loss: 0.1728307024428719 validation loss: 0.16767960973083973
# No improvement on validation loss
#
# epoch 58/150 training loss: 0.1670608026416678 validation loss: 0.15720473416149616
# No improvement on validation loss
#
# epoch 59/150 training loss: 0.16944351713908345 validation loss: 0.1572805605828762
# No improvement on validation loss
#
# epoch 60/150 training loss: 0.1685676308054673 validation loss: 0.15909809060394764
# No improvement on validation loss
#
# epoch 61/150 training loss: 0.16839216649532318 validation loss: 0.16016560979187489
# No improvement on validation loss
#
# epoch 62/150 training loss: 0.1709808095505363 validation loss: 0.1577630750834942
# No improvement on validation loss
#
# epoch 63/150 training loss: 0.16380100658065394 validation loss: 0.16424466110765934
# No improvement on validation loss
#
# epoch 64/150 training loss: 0.1670629139009275 validation loss: 0.15354136377573013
# New minimum validation loss
#
# epoch 65/150 training loss: 0.16691428893490842 validation loss: 0.15343688242137432
# New minimum validation loss
#
# epoch 66/150 training loss: 0.16863224773030533 validation loss: 0.1593017652630806
# No improvement on validation loss
#
# epoch 67/150 training loss: 0.16681376334867978 validation loss: 0.1595056988298893
# No improvement on validation loss
#
# epoch 68/150 training loss: 0.16321271030526413 validation loss: 0.16126850619912148
# No improvement on validation loss
#
# epoch 69/150 training loss: 0.16298608560311167 validation loss: 0.16005361266434193
# No improvement on validation loss
#
# epoch 70/150 training loss: 0.16343168286900772 validation loss: 0.1558326929807663
# No improvement on validation loss
#
# epoch 71/150 training loss: 0.16140426224783846 validation loss: 0.15488586761057377
# No improvement on validation loss
#
# epoch 72/150 training loss: 0.16325222896902183 validation loss: 0.1570714544504881
# No improvement on validation loss
#
# epoch 73/150 training loss: 0.16119074272482017 validation loss: 0.15300532896071672
# New minimum validation loss
#
# epoch 74/150 training loss: 0.16524380053344526 validation loss: 0.15661142393946648
# No improvement on validation loss
#
# epoch 75/150 training loss: 0.1599776156638798 validation loss: 0.15236355550587177
# New minimum validation loss
#
# epoch 76/150 training loss: 0.16180472781783656 validation loss: 0.15293031185865402
# No improvement on validation loss
#
# epoch 77/150 training loss: 0.15967953675671628 validation loss: 0.15454159304499626
# No improvement on validation loss
#
# epoch 78/150 training loss: 0.1615621682844664 validation loss: 0.15690753981471062
# No improvement on validation loss
#
# epoch 79/150 training loss: 0.16946076797811607 validation loss: 0.1540493667125702
# No improvement on validation loss
#
# epoch 80/150 training loss: 0.16523028125888423 validation loss: 0.15961605682969093
# No improvement on validation loss
#
# epoch 81/150 training loss: 0.16140555904099815 validation loss: 0.1543309846892953
# No improvement on validation loss
#
# epoch 82/150 training loss: 0.15909781267768458 validation loss: 0.1540686208754778
# No improvement on validation loss
#
# epoch 83/150 training loss: 0.1589258909225464 validation loss: 0.157771248370409
# No improvement on validation loss
#
# epoch 84/150 training loss: 0.15937575305763044 validation loss: 0.15837362222373486
# No improvement on validation loss
#
# epoch 85/150 training loss: 0.1602606459667808 validation loss: 0.15452280081808567
# No improvement on validation loss
#
# epoch 86/150 training loss: 0.15433955192565918 validation loss: 0.15944031812250614
# No improvement on validation loss
#
# epoch 87/150 training loss: 0.15931044832656258 validation loss: 0.15962490253150463
# No improvement on validation loss
#
# epoch 88/150 training loss: 0.15787916669720098 validation loss: 0.15210025198757648
# New minimum validation loss
#
# epoch 89/150 training loss: 0.1578158532318316 validation loss: 0.15614245645701885
# No improvement on validation loss
#
# epoch 90/150 training loss: 0.1611968431817858 validation loss: 0.15322943218052387
# No improvement on validation loss
#
# epoch 91/150 training loss: 0.16391666547248238 validation loss: 0.15824339352548122
# No improvement on validation loss
#
# epoch 92/150 training loss: 0.1580811919350373 validation loss: 0.15372616052627563
# No improvement on validation loss
#
# epoch 93/150 training loss: 0.15927698345560776 validation loss: 0.1554706208407879
# No improvement on validation loss
#
# epoch 94/150 training loss: 0.16386666188114568 validation loss: 0.1559140495955944
# No improvement on validation loss
#
# epoch 95/150 training loss: 0.16390321991945567 validation loss: 0.15816838666796684
# No improvement on validation loss
#
# epoch 96/150 training loss: 0.1583896451874783 validation loss: 0.15760777331888676
# No improvement on validation loss
#
# epoch 97/150 training loss: 0.15425512469128558 validation loss: 0.15656101517379284
# No improvement on validation loss
#
# epoch 98/150 training loss: 0.15445123612880707 validation loss: 0.15258501283824444
# No improvement on validation loss
#
# epoch 99/150 training loss: 0.1584932631567905 validation loss: 0.1556723527610302
# No improvement on validation loss
#
# epoch 100/150 training loss: 0.15195483910410026 validation loss: 0.14961959701031446
# New minimum validation loss
#
# epoch 101/150 training loss: 0.15820080826157018 validation loss: 0.15166443213820457
# No improvement on validation loss
#
# epoch 102/150 training loss: 0.15932538634852358 validation loss: 0.1625499092042446
# No improvement on validation loss
#
# epoch 103/150 training loss: 0.1561064351546137 validation loss: 0.16774424351751804
# No improvement on validation loss
#
# epoch 104/150 training loss: 0.1548758231495556 validation loss: 0.15660535916686058
# No improvement on validation loss
#
# epoch 105/150 training loss: 0.15684803771345238 validation loss: 0.16506792046129704
# No improvement on validation loss
#
# epoch 106/150 training loss: 0.15400975158340052 validation loss: 0.15423222444951534
# No improvement on validation loss
#
# epoch 107/150 training loss: 0.1548795845163496 validation loss: 0.1535395234823227
# No improvement on validation loss
#
# epoch 108/150 training loss: 0.15949481098275436 validation loss: 0.154171759262681
# No improvement on validation loss
#
# epoch 109/150 training loss: 0.1532382972930607 validation loss: 0.15158354677259922
# No improvement on validation loss
#
# epoch 110/150 training loss: 0.15428422391414642 validation loss: 0.1526794144883752
# No improvement on validation loss
#
# epoch 111/150 training loss: 0.14956837343542198 validation loss: 0.1549391932785511
# No improvement on validation loss
#
# epoch 112/150 training loss: 0.15645916995249295 validation loss: 0.1572583131492138
# No improvement on validation loss
#
# epoch 113/150 training loss: 0.15789030962868741 validation loss: 0.15427385084331036
# No improvement on validation loss
#
# epoch 114/150 training loss: 0.1571863944593229 validation loss: 0.1489490894600749
# New minimum validation loss
#
# epoch 115/150 training loss: 0.1547277946221201 validation loss: 0.15309114940464497
# No improvement on validation loss
#
# epoch 116/150 training loss: 0.1557673180573865 validation loss: 0.15864779986441135
# No improvement on validation loss
#
# epoch 117/150 training loss: 0.15464931491174197 validation loss: 0.15150244534015656
# No improvement on validation loss
#
# epoch 118/150 training loss: 0.15676931017323545 validation loss: 0.1530932355672121
# No improvement on validation loss
#
# epoch 119/150 training loss: 0.1531669756299571 validation loss: 0.15498200058937073
# No improvement on validation loss
#
# epoch 120/150 training loss: 0.15258077571266576 validation loss: 0.15599265694618225
# No improvement on validation loss
#
# epoch 121/150 training loss: 0.1573168070692765 validation loss: 0.16159086115658283
# No improvement on validation loss
#
# epoch 122/150 training loss: 0.15241410073481107 validation loss: 0.15198722667992115
# No improvement on validation loss
#
# epoch 123/150 training loss: 0.15420203459890267 validation loss: 0.15212224796414375
# No improvement on validation loss
#
# epoch 124/150 training loss: 0.15171310776158384 validation loss: 0.16099102422595024
# No improvement on validation loss
#
# epoch 125/150 training loss: 0.15099756694153735 validation loss: 0.15393058583140373
# No improvement on validation loss
#
# epoch 126/150 training loss: 0.15568556597358302 validation loss: 0.1561618447303772
# No improvement on validation loss
#
# epoch 127/150 training loss: 0.15206013541472585 validation loss: 0.15281056985259056
# No improvement on validation loss
#
# epoch 128/150 training loss: 0.15072544154367948 validation loss: 0.15563875436782837
# No improvement on validation loss
#
# epoch 129/150 training loss: 0.15221615723873438 validation loss: 0.15016012080013752
# No improvement on validation loss
#
# epoch 130/150 training loss: 0.15000616406139575 validation loss: 0.147630387917161
# New minimum validation loss
#
# epoch 131/150 training loss: 0.15555151669602646 validation loss: 0.15118922665715218
# No improvement on validation loss
#
# epoch 132/150 training loss: 0.15104894418465464 validation loss: 0.15443096868693829
# No improvement on validation loss
#
# epoch 133/150 training loss: 0.1561975596766723 validation loss: 0.15612218528985977
# No improvement on validation loss
#
# epoch 134/150 training loss: 0.15241178438851707 validation loss: 0.15048148483037949
# No improvement on validation loss
#
# epoch 135/150 training loss: 0.14787060963480095 validation loss: 0.14841006230562925
# No improvement on validation loss
#
# epoch 136/150 training loss: 0.14865718389812269 validation loss: 0.15625008381903172
# No improvement on validation loss
#
# epoch 137/150 training loss: 0.14697870141581484 validation loss: 0.15083586610853672
# No improvement on validation loss
#
# epoch 138/150 training loss: 0.14529794650642494 validation loss: 0.15260892920196056
# No improvement on validation loss
#
# epoch 139/150 training loss: 0.14585760549495094 validation loss: 0.16181674227118492
# No improvement on validation loss
#
# epoch 140/150 training loss: 0.16935917029255315 validation loss: 0.15580524876713753
# No improvement on validation loss
#
# epoch 141/150 training loss: 0.1630274363254246 validation loss: 0.15843575075268745
# No improvement on validation loss
#
# epoch 142/150 training loss: 0.15901089498871251 validation loss: 0.15210416167974472
# No improvement on validation loss
#
# epoch 143/150 training loss: 0.15832539451749703 validation loss: 0.15487962029874325
# No improvement on validation loss
#
# epoch 144/150 training loss: 0.15604088886788017 validation loss: 0.16561759822070599
# No improvement on validation loss
#
# epoch 145/150 training loss: 0.1563511612383943 validation loss: 0.15614252537488937
# No improvement on validation loss
#
# epoch 146/150 training loss: 0.16258637607097626 validation loss: 0.1564797181636095
# No improvement on validation loss
#
# epoch 147/150 training loss: 0.17380567208716743 validation loss: 0.16044047474861145
# No improvement on validation loss
#
# epoch 148/150 training loss: 0.16572563036491997 validation loss: 0.160433204844594
# No improvement on validation loss
#
# epoch 149/150 training loss: 0.15466915776855067 validation loss: 0.14478227775543928
# New minimum validation loss
# Best validation error 0.1448 is achieved at epoch 149
# Test loss 0.1427.

# %%
training_losses = ret_dict['training_losses']
val_losses = ret_dict['val_losses']
best_epoch = ret_dict['best_epoch']

plt.plot(training_losses, label='training')
plt.plot(val_losses, label='validation')
plt.scatter([best_epoch], [val_losses[best_epoch]], label='best epoch', color='r')
plt.title('losses (with data augmentation)')
plt.xlabel('n_epoch')
plt.ylim([0,0.7])
# plt.savefig(os.path.join(base_path,'images/train_loss.png'))
plt.legend()
plt.show()

# %% [markdown]
# training loss aggregated vs val loss final (best) of epoch

# %% [markdown]
# compare with training without data augmentation

# %%
model = UNet(n_channels=1, n_classes=4).to(DEVICE)

ret_dict = train(model, train_loader_wo_da, val_loader, test_loader,'saved_models/wo_da.pt')
# Out:
# epoch 0/150 training loss: 0.6265178793355038 validation loss: 0.40055012330412865
# New minimum validation loss
#
# epoch 1/150 training loss: 0.3462530201987216 validation loss: 0.3153015822172165
# New minimum validation loss
#
# epoch 2/150 training loss: 0.2840791870104639 validation loss: 0.2665345072746277
# New minimum validation loss
#
# epoch 3/150 training loss: 0.25990199023171473 validation loss: 0.26786826364696026
# No improvement on validation loss
#
# epoch 4/150 training loss: 0.24524267331549995 validation loss: 0.24071419052779675
# New minimum validation loss
#
# epoch 5/150 training loss: 0.22917183841529645 validation loss: 0.22057720459997654
# New minimum validation loss
#
# epoch 6/150 training loss: 0.20515907751886467 validation loss: 0.20800579525530338
# New minimum validation loss
#
# epoch 7/150 training loss: 0.20214491298324183 validation loss: 0.22078274376690388
# No improvement on validation loss
#
# epoch 8/150 training loss: 0.20326690297377736 validation loss: 0.2059985101222992
# New minimum validation loss
#
# epoch 9/150 training loss: 0.18626474314614347 validation loss: 0.2005448341369629
# New minimum validation loss
#
# epoch 10/150 training loss: 0.18206403365260676 validation loss: 0.19123602099716663
# New minimum validation loss
#
# epoch 11/150 training loss: 0.17589013121630015 validation loss: 0.19782361201941967
# No improvement on validation loss
#
# epoch 12/150 training loss: 0.1765568428917935 validation loss: 0.18275996670126915
# New minimum validation loss
#
# epoch 13/150 training loss: 0.16667250504619197 validation loss: 0.18107963539659977
# New minimum validation loss
#
# epoch 14/150 training loss: 0.16664324269482964 validation loss: 0.1763884425163269
# New minimum validation loss
#
# epoch 15/150 training loss: 0.1656394577340076 validation loss: 0.17707908153533936
# No improvement on validation loss
#
# epoch 16/150 training loss: 0.16265666327978434 validation loss: 0.18190348893404007
# No improvement on validation loss
#
# epoch 17/150 training loss: 0.1611151287430211 validation loss: 0.17353492975234985
# New minimum validation loss
#
# epoch 18/150 training loss: 0.15588048100471497 validation loss: 0.17111950553953648
# New minimum validation loss
#
# epoch 19/150 training loss: 0.15234483229486565 validation loss: 0.17015191540122032
# New minimum validation loss
#
# epoch 20/150 training loss: 0.15257741903003894 validation loss: 0.1751217544078827
# No improvement on validation loss
#
# epoch 21/150 training loss: 0.1499559008761456 validation loss: 0.1679142229259014
# New minimum validation loss
#
# epoch 22/150 training loss: 0.1507433794046703 validation loss: 0.16773438826203346
# New minimum validation loss
#
# epoch 23/150 training loss: 0.1446333386396107 validation loss: 0.16524894908070564
# New minimum validation loss
#
# epoch 24/150 training loss: 0.14239327335043958 validation loss: 0.16389856673777103
# New minimum validation loss
#
# epoch 25/150 training loss: 0.13949714797107796 validation loss: 0.16098612919449806
# New minimum validation loss
#
# epoch 26/150 training loss: 0.14327096233242437 validation loss: 0.1676828283816576
# No improvement on validation loss
#
# epoch 27/150 training loss: 0.14045195399146332 validation loss: 0.16143282316625118
# No improvement on validation loss
#
# epoch 28/150 training loss: 0.14091058545990995 validation loss: 0.16552172601222992
# No improvement on validation loss
#
# epoch 29/150 training loss: 0.13691264508586182 validation loss: 0.16153629310429096
# No improvement on validation loss
#
# epoch 30/150 training loss: 0.13790801873332575 validation loss: 0.1654155794531107
# No improvement on validation loss
#
# epoch 31/150 training loss: 0.1372731645640574 validation loss: 0.1600346937775612
# New minimum validation loss
#
# epoch 32/150 training loss: 0.13407674078878604 validation loss: 0.17205135338008404
# No improvement on validation loss
#
# epoch 33/150 training loss: 0.13434154422659622 validation loss: 0.15530355460941792
# New minimum validation loss
#
# epoch 34/150 training loss: 0.1293443460997782 validation loss: 0.1570698358118534
# No improvement on validation loss
#
# epoch 35/150 training loss: 0.12748680577466362 validation loss: 0.15427390299737453
# New minimum validation loss
#
# epoch 36/150 training loss: 0.12804950185512243 validation loss: 0.15792986750602722
# No improvement on validation loss
#
# epoch 37/150 training loss: 0.12862494117335269 validation loss: 0.15595479309558868
# No improvement on validation loss
#
# epoch 38/150 training loss: 0.12704781913443616 validation loss: 0.16757878474891186
# No improvement on validation loss
#
# epoch 39/150 training loss: 0.13270278549508044 validation loss: 0.16813211888074875
# No improvement on validation loss
#
# epoch 40/150 training loss: 0.13277415029312434 validation loss: 0.15672047436237335
# No improvement on validation loss
#
# epoch 41/150 training loss: 0.1290675962441846 validation loss: 0.16317792609333992
# No improvement on validation loss
#
# epoch 42/150 training loss: 0.12832282954140714 validation loss: 0.15936441905796528
# No improvement on validation loss
#
# epoch 43/150 training loss: 0.12226158811857826 validation loss: 0.15437890216708183
# No improvement on validation loss
#
# epoch 44/150 training loss: 0.11913923448637913 validation loss: 0.1527702361345291
# New minimum validation loss
#
# epoch 45/150 training loss: 0.12351807402937036 validation loss: 0.1545903217047453
# No improvement on validation loss
#
# epoch 46/150 training loss: 0.12743750293003886 validation loss: 0.15735815092921257
# No improvement on validation loss
#
# epoch 47/150 training loss: 0.12298790914447684 validation loss: 0.15728602930903435
# No improvement on validation loss
#
# epoch 48/150 training loss: 0.1247401088476181 validation loss: 0.15670148096978664
# No improvement on validation loss
#
# epoch 49/150 training loss: 0.12261030626924414 validation loss: 0.15257089957594872
# New minimum validation loss
#
# epoch 50/150 training loss: 0.11742584446543142 validation loss: 0.15623543038964272
# No improvement on validation loss
#
# epoch 51/150 training loss: 0.1226528643777496 validation loss: 0.15238560177385807
# New minimum validation loss
#
# epoch 52/150 training loss: 0.1153140609201632 validation loss: 0.1523960717022419
# No improvement on validation loss
#
# epoch 53/150 training loss: 0.11313133529926601 validation loss: 0.14950417913496494
# New minimum validation loss
#
# epoch 54/150 training loss: 0.11094625803985093 validation loss: 0.15078134462237358
# No improvement on validation loss
#
# epoch 55/150 training loss: 0.11640673640527223 validation loss: 0.15460052900016308
# No improvement on validation loss
#
# epoch 56/150 training loss: 0.11491008338175322 validation loss: 0.15158738568425179
# No improvement on validation loss
#
# epoch 57/150 training loss: 0.1170773659097521 validation loss: 0.1519853938370943
# No improvement on validation loss
#
# epoch 58/150 training loss: 0.1156818521650214 validation loss: 0.15521950833499432
# No improvement on validation loss
#
# epoch 59/150 training loss: 0.11644844946108367 validation loss: 0.15365231223404408
# No improvement on validation loss
#
# epoch 60/150 training loss: 0.11566077721746344 validation loss: 0.15712609514594078
# No improvement on validation loss
#
# epoch 61/150 training loss: 0.13051379393590123 validation loss: 0.17861780151724815
# No improvement on validation loss
#
# epoch 62/150 training loss: 0.12970828461019615 validation loss: 0.15813364833593369
# No improvement on validation loss
#
# epoch 63/150 training loss: 0.11638845346475903 validation loss: 0.15436866879463196
# No improvement on validation loss
#
# epoch 64/150 training loss: 0.11544597972380488 validation loss: 0.15432805381715298
# No improvement on validation loss
#
# epoch 65/150 training loss: 0.11853728913947155 validation loss: 0.15949250012636185
# No improvement on validation loss
#
# epoch 66/150 training loss: 0.11916990068398024 validation loss: 0.15020091272890568
# No improvement on validation loss
#
# epoch 67/150 training loss: 0.1142245750678213 validation loss: 0.15001380629837513
# No improvement on validation loss
#
# epoch 68/150 training loss: 0.11194506169934022 validation loss: 0.1493045575916767
# New minimum validation loss
#
# epoch 69/150 training loss: 0.10542949132229153 validation loss: 0.14867309294641018
# New minimum validation loss
#
# epoch 70/150 training loss: 0.10842868607295186 validation loss: 0.15036889724433422
# No improvement on validation loss
#
# epoch 71/150 training loss: 0.10683734950266387 validation loss: 0.15352709963917732
# No improvement on validation loss
#
# epoch 72/150 training loss: 0.10504609189535442 validation loss: 0.1506122536957264
# No improvement on validation loss
#
# epoch 73/150 training loss: 0.1048693927495103 validation loss: 0.15228793770074844
# No improvement on validation loss
#
# epoch 74/150 training loss: 0.10734866873214119 validation loss: 0.1520900409668684
# No improvement on validation loss
#
# epoch 75/150 training loss: 0.10505358835584239 validation loss: 0.15170960873365402
# No improvement on validation loss
#
# epoch 76/150 training loss: 0.102406082576827 validation loss: 0.15318277291953564
# No improvement on validation loss
#
# epoch 77/150 training loss: 0.10378337298568927 validation loss: 0.15028221160173416
# No improvement on validation loss
#
# epoch 78/150 training loss: 0.10362616965645238 validation loss: 0.14933301880955696
# No improvement on validation loss
#
# epoch 79/150 training loss: 0.10581338052686892 validation loss: 0.1554152462631464
# No improvement on validation loss
#
# epoch 80/150 training loss: 0.10286999376196611 validation loss: 0.15124117955565453
# No improvement on validation loss
#
# epoch 81/150 training loss: 0.10336038234986757 validation loss: 0.15275455079972744
# No improvement on validation loss
#
# epoch 82/150 training loss: 0.10034764479649694 validation loss: 0.15382256358861923
# No improvement on validation loss
#
# epoch 83/150 training loss: 0.10199934989213943 validation loss: 0.15289492905139923
# No improvement on validation loss
#
# epoch 84/150 training loss: 0.10364785515948345 validation loss: 0.15613598562777042
# No improvement on validation loss
#
# epoch 85/150 training loss: 0.102572054063019 validation loss: 0.15242205373942852
# No improvement on validation loss
#
# epoch 86/150 training loss: 0.10242744770489241 validation loss: 0.15390151739120483
# No improvement on validation loss
#
# epoch 87/150 training loss: 0.10278722447784323 validation loss: 0.1534954570233822
# No improvement on validation loss
#
# epoch 88/150 training loss: 0.10067396532548101 validation loss: 0.15064425393939018
# No improvement on validation loss
#
# epoch 89/150 training loss: 0.0964440256357193 validation loss: 0.15167461335659027
# No improvement on validation loss
#
# epoch 90/150 training loss: 0.0978067129066116 validation loss: 0.15485456213355064
# No improvement on validation loss
#
# epoch 91/150 training loss: 0.09464926900048005 validation loss: 0.1506245844066143
# No improvement on validation loss
#
# epoch 92/150 training loss: 0.0960992398230653 validation loss: 0.1530749499797821
# No improvement on validation loss
#
# epoch 93/150 training loss: 0.09796475226941861 validation loss: 0.15138866566121578
# No improvement on validation loss
#
# epoch 94/150 training loss: 0.09895125894170058 validation loss: 0.15302938409149647
# No improvement on validation loss
#
# epoch 95/150 training loss: 0.09716468069114183 validation loss: 0.14947680942714214
# No improvement on validation loss
#
# epoch 96/150 training loss: 0.09693745209982521 validation loss: 0.1537054404616356
# No improvement on validation loss
#
# epoch 97/150 training loss: 0.09657790864768781 validation loss: 0.15277870930731297
# No improvement on validation loss
#
# epoch 98/150 training loss: 0.0937755037295191 validation loss: 0.15292399749159813
# No improvement on validation loss
#
# epoch 99/150 training loss: 0.09604020887299587 validation loss: 0.15190474316477776
# No improvement on validation loss
#
# epoch 100/150 training loss: 0.099575553677584 validation loss: 0.15514096803963184
# No improvement on validation loss
#
# epoch 101/150 training loss: 0.09760708950067822 validation loss: 0.1601948570460081
# No improvement on validation loss
#
# epoch 102/150 training loss: 0.10044203816275847 validation loss: 0.15616611577570438
# No improvement on validation loss
#
# epoch 103/150 training loss: 0.09882699580569017 validation loss: 0.14864359609782696
# New minimum validation loss
#
# epoch 104/150 training loss: 0.09154754484954633 validation loss: 0.15019278600811958
# No improvement on validation loss
#
# epoch 105/150 training loss: 0.09149905607888573 validation loss: 0.1508154198527336
# No improvement on validation loss
#
# epoch 106/150 training loss: 0.08832794114163048 validation loss: 0.1526788081973791
# No improvement on validation loss
#
# epoch 107/150 training loss: 0.09067011585361079 validation loss: 0.14849910140037537
# New minimum validation loss
#
# epoch 108/150 training loss: 0.09140904032086071 validation loss: 0.15342597477138042
# No improvement on validation loss
#
# epoch 109/150 training loss: 0.09365133901959971 validation loss: 0.15276080928742886
# No improvement on validation loss
#
# epoch 110/150 training loss: 0.090376090062292 validation loss: 0.15015720576047897
# No improvement on validation loss
#
# epoch 111/150 training loss: 0.09136009020240683 validation loss: 0.15172737278044224
# No improvement on validation loss
#
# epoch 112/150 training loss: 0.09052694334011328 validation loss: 0.151434026658535
# No improvement on validation loss
#
# epoch 113/150 training loss: 0.09035555175260494 validation loss: 0.15146519988775253
# No improvement on validation loss
#
# epoch 114/150 training loss: 0.08959612720891048 validation loss: 0.15373374707996845
# No improvement on validation loss
#
# epoch 115/150 training loss: 0.09206109023407887 validation loss: 0.1533372364938259
# No improvement on validation loss
#
# epoch 116/150 training loss: 0.08957459150176299 validation loss: 0.15228329971432686
# No improvement on validation loss
#
# epoch 117/150 training loss: 0.08795784923591111 validation loss: 0.15065661445260048
# No improvement on validation loss
#
# epoch 118/150 training loss: 0.08610787281864568 validation loss: 0.1520139779895544
# No improvement on validation loss
#
# epoch 119/150 training loss: 0.08496402635386116 validation loss: 0.15180235542356968
# No improvement on validation loss
#
# epoch 120/150 training loss: 0.08874342904279106 validation loss: 0.153932586312294
# No improvement on validation loss
#
# epoch 121/150 training loss: 0.08987661804023542 validation loss: 0.1516908761113882
# No improvement on validation loss
#
# epoch 122/150 training loss: 0.09026088173452176 validation loss: 0.1524774171411991
# No improvement on validation loss
#
# epoch 123/150 training loss: 0.0875337676782357 validation loss: 0.15203909948468208
# No improvement on validation loss
#
# epoch 124/150 training loss: 0.08843220613504711 validation loss: 0.15126988478004932
# No improvement on validation loss
#
# epoch 125/150 training loss: 0.0868522558165224 validation loss: 0.15254381857812405
# No improvement on validation loss
#
# epoch 126/150 training loss: 0.09477531164884567 validation loss: 0.1503812987357378
# No improvement on validation loss
#
# epoch 127/150 training loss: 0.09097244590520859 validation loss: 0.15378972329199314
# No improvement on validation loss
#
# epoch 128/150 training loss: 0.08877072757796238 validation loss: 0.15008044987916946
# No improvement on validation loss
#
# epoch 129/150 training loss: 0.08524085698943389 validation loss: 0.15034031495451927
# No improvement on validation loss
#
# epoch 130/150 training loss: 0.08261625605978463 validation loss: 0.1507568359375
# No improvement on validation loss
#
# epoch 131/150 training loss: 0.08275978600508288 validation loss: 0.15192506089806557
# No improvement on validation loss
#
# epoch 132/150 training loss: 0.08438333751339662 validation loss: 0.15318979881703854
# No improvement on validation loss
#
# epoch 133/150 training loss: 0.0825051226113972 validation loss: 0.15140043571591377
# No improvement on validation loss
#
# epoch 134/150 training loss: 0.08283329794281408 validation loss: 0.1499099489301443
# No improvement on validation loss
#
# epoch 135/150 training loss: 0.0936737080153666 validation loss: 0.18711757101118565
# No improvement on validation loss
#
# epoch 136/150 training loss: 0.19002564290636464 validation loss: 0.19410376995801926
# No improvement on validation loss
#
# epoch 137/150 training loss: 0.17096038946979925 validation loss: 0.20815419405698776
# No improvement on validation loss
#
# epoch 138/150 training loss: 0.21403953197755313 validation loss: 0.19914556108415127
# No improvement on validation loss
#
# epoch 139/150 training loss: 0.17221052160388545 validation loss: 0.17463523522019386
# No improvement on validation loss
#
# epoch 140/150 training loss: 0.15247034359919398 validation loss: 0.17080444283783436
# No improvement on validation loss
#
# epoch 141/150 training loss: 0.1413867348118832 validation loss: 0.16026964224874973
# No improvement on validation loss
#
# epoch 142/150 training loss: 0.1355243803639161 validation loss: 0.16560111567378044
# No improvement on validation loss
#
# epoch 143/150 training loss: 0.13446865505293795 validation loss: 0.1551937609910965
# No improvement on validation loss
#
# epoch 144/150 training loss: 0.13285292018400996 validation loss: 0.1551708858460188
# No improvement on validation loss
#
# epoch 145/150 training loss: 0.13883238717129356 validation loss: 0.15134291350841522
# No improvement on validation loss
#
# epoch 146/150 training loss: 0.11748349627381877 validation loss: 0.15935946442186832
# No improvement on validation loss
#
# epoch 147/150 training loss: 0.13016936810393082 validation loss: 0.16746816970407963
# No improvement on validation loss
#
# epoch 148/150 training loss: 0.12494016556363356 validation loss: 0.15265090204775333
# No improvement on validation loss
#
# epoch 149/150 training loss: 0.12363178596684807 validation loss: 0.19728340208530426
# No improvement on validation loss
# Best validation error 0.1485 is achieved at epoch 107
# Test loss 0.1558.

# %%
training_losses = ret_dict['training_losses']
val_losses = ret_dict['val_losses']
best_epoch = ret_dict['best_epoch']

plt.plot(training_losses, label='training')
plt.plot(val_losses, label='validation')
plt.scatter([best_epoch], [val_losses[best_epoch]], label='best epoch', color='r')
plt.title('losses (without data augmentation)')
plt.xlabel('n_epoch')
plt.ylim([0,0.7])
# plt.savefig(os.path.join(base_path,'images/train_loss.png'))
plt.legend()
plt.show()

# %% [markdown]
# ## Performance on test set
#
# load from pretrained weights

# %%
from unet import UNet

# %%
model_w = UNet(n_channels=1, n_classes=4).to(DEVICE)
model_w.load_state_dict(torch.load('saved_models/w_da.pt', map_location=DEVICE))

model_wo = UNet(n_channels=1, n_classes=4).to(DEVICE)
model_wo.load_state_dict(torch.load('saved_models/wo_da.pt', map_location=DEVICE))

print('Weights loaded')
# Out:
# Weights loaded

# %%
# test loss
dice_func = monai.losses.DiceLoss(softmax=True, to_onehot_y=True)

# cross entropy loss
def CE_func(inputs, target):
    target = torch.squeeze(target, dim=1)
    target = target.long()
    loss = torch.nn.CrossEntropyLoss()(inputs, target)
    return loss

dice_loss = compute_eval_loss(model_w, test_loader, dice_func)
CE_loss = compute_eval_loss(model_w, test_loader, CE_func)
print(f'w. data augmentation: DICE loss {dice_loss:.4f} CE loss {CE_loss:.4f}')

dice_loss = compute_eval_loss(model_wo, test_loader, dice_func)
CE_loss = compute_eval_loss(model_wo, test_loader, CE_func)
print(f'w.o. data augmentation: DICE loss {dice_loss:.4f} CE loss {CE_loss:.4f}')
# Out:
# w. data augmentation: DICE loss 0.1276 CE loss 0.1510
# w.o. data augmentation: DICE loss 0.1320 CE loss 0.2379

# %%
postprocess = monai.transforms.Compose([
    monai.transforms.Activations(softmax=True, dim=1),
    monai.transforms.AsDiscrete(argmax=True, to_onehot=4, dim=1),
    monai.transforms.KeepLargestConnectedComponent(applied_labels=(1, 2, 3), independent=False, connectivity=None)
    # TODO: more postprocess
])

def test_performance(model, test_loader):
    model.eval()

    dscs_list = []

    dice_metric = monai.metrics.DiceMetric(include_background=False, # exclude background
                                           # reduction = None,
                                        ignore_empty=True)
    # hd_metric = monai.metrics.HausdorffDistanceMetric()

    for i, test_batch in enumerate(test_loader):

        test_input = test_batch[0]
        with torch.no_grad():
            outputs_test = model(test_input.to(DEVICE))

        outputs_test = postprocess(outputs_test) # (BS, 4, H, W) a 0-1 mask for 4 classes

        y_pred = outputs_test.cpu()
        y_gt = monai.networks.utils.one_hot(test_batch[1],dim=1,num_classes=4)

        dsc = dice_metric(y_pred, y_gt)
        dscs_list.append(dsc)

        # hd = hd_metric(y_pred, y_gt)
        # hds[i] = np.nanmean(hd.numpy(),axis=0)

    dscs = np.concatenate(dscs_list, axis=0)
    print(f'average DICE score on test set: {np.nanmean(dscs):.3f}')
    print(f'average DICE score on test set for class 1: {np.nanmean(dscs[:,0]):.3f}')
    print(f'average DICE score on test set for class 2: {np.nanmean(dscs[:,1]):.3f}')
    print(f'average DICE score on test set for class 3: {np.nanmean(dscs[:,2]):.3f}')
    return dscs

# %%
print('w. data augmentation')
dscs_w = test_performance(model_w, test_loader)
print('w.o. data augmentation')
dscs_wo = test_performance(model_wo, test_loader)
# Out:
# w. data augmentation
# average DICE score on test set: 0.893
# average DICE score on test set for class 1: 0.882
# average DICE score on test set for class 2: 0.872
# average DICE score on test set for class 3: 0.923
# w.o. data augmentation
# average DICE score on test set: 0.883
# average DICE score on test set for class 1: 0.859
# average DICE score on test set for class 2: 0.868
# average DICE score on test set for class 3: 0.919

# %%
def get_best_worst_batch(dscs, label=0, n=10):
    '''
    Args:
        dscs: array of dice metrics (
        label: get the best/worst performance of class<label>, if 0 return best/worst average
    '''
    if label==0:
        dsc_val = np.nanmean(dscs, axis=1)
    else:
        dsc_val = dscs[:,label-1]
    sorted_val = np.sort(dsc_val)
    sorted_indices = np.argsort(dsc_val)

    if np.isnan(sorted_val).any():
        nan_start_index = (np.isnan(sorted_val)).argmax()
        sorted_indices = sorted_indices[:nan_start_index]

    # smallest (resp. biggest) DICE metrics - worst (resp. best) performance
    worst_indices = sorted_indices[:n]
    best_indices = sorted_indices[-n:][::-1]

    return worst_indices, best_indices

def predict_label(model, test_batch, visualize=False):
    test_input = test_batch[0]

    with torch.no_grad():
        outputs_test = model(test_input.to(DEVICE))

    outputs_test = postprocess(outputs_test) # (BS, 4, H, W) a 0-1 mask for 4 classes

    y_pred = outputs_test.cpu()
    y_gt = monai.networks.utils.one_hot(test_batch[1],dim=1,num_classes=4)


    if visualize:
        label_pred = torch.argmax(outputs_test, dim=1).cpu()
        label_gt = test_batch[1].squeeze()

        print('ground truth')
        util.visualize_3D({"image": test_input[:,0].permute(1,2,0),
                           "label": label_gt[:].permute(1,2,0)})

        print('prediction')
        util.visualize_3D({"image": test_input[:,0].permute(1,2,0),
                           "label": label_pred[:].permute(1,2,0)})

# %% [markdown]
# ## Worst/best average performance

# %% [markdown]
# ### all 3 labels

# %%
worst_indices_mean, best_indices_mean = get_best_worst_batch(dscs_w, label=0, n=5)
worst_batch = (test_X[worst_indices_mean.copy()], test_Y[worst_indices_mean.copy()])
best_batch = (test_X[best_indices_mean.copy()], test_Y[best_indices_mean.copy()])
worst_indices_mean, best_indices_mean
# Out:
# (array([528, 518, 426, 691, 367]), array([693, 570, 779, 239, 248]))

# %%
predict_label(model_w, worst_batch, visualize=True)
# Out:
# ground truth
# prediction

# %%
predict_label(model_w, best_batch, visualize=True)
# show corresponding DICE TODO
# Out:
# ground truth
# prediction

# %% [markdown]
# ### class 1 (red)

# %%
worst_indices, best_indices = get_best_worst_batch(dscs_w, label=1, n=5)
worst_batch = (test_X[worst_indices.copy()], test_Y[worst_indices.copy()])
best_batch = (test_X[best_indices.copy()], test_Y[best_indices.copy()])
predict_label(model_w, worst_batch, visualize=True)
# predict_label(model_w, best_batch, visualize=True)
# Out:
# worst/best performance of class 1 (red)
# ground truth
# prediction

# %% [markdown]
# ### class 2 (green)

# %%
worst_indices, best_indices = get_best_worst_batch(dscs_w, label=2, n=5)
worst_batch = (test_X[worst_indices.copy()], test_Y[worst_indices.copy()])
best_batch = (test_X[best_indices.copy()], test_Y[best_indices.copy()])
predict_label(model_w, worst_batch, visualize=True)
# predict_label(model_w, best_batch, visualize=True)
# Out:
# worst/best performance of class 2 (green)
# ground truth
# prediction

# %% [markdown]
# ### class 3 (blue)

# %%
worst_indices, best_indices = get_best_worst_batch(dscs_w, label=3, n=5)
worst_batch = (test_X[worst_indices.copy()], test_Y[worst_indices.copy()])
best_batch = (test_X[best_indices.copy()], test_Y[best_indices.copy()])
predict_label(model_w, worst_batch, visualize=True)
# predict_label(model_w, best_batch, visualize=True)
# Out:
# worst/best performance of class 3 (blue)
# ground truth
# prediction

# %%
slices = [test_data[i][0].shape[0] for i in range(len(test_data))]
slice_idx = np.cumsum([0] + slices)

# %%
score_per_slice = np.zeros((11,3))
num_per_slice = np.zeros((11,3))
for i in range(len(test_data)):
    sli = slices[i]
    center = sli//2
    off = 5-center
    for j in range(sli):
        score_per_slice[off+j] += np.nan_to_num(dscs_w[slice_idx[i]+j])
        num_per_slice[off+j] += 1-np.isnan(dscs_w[slice_idx[i]+j])

# %%
scores = np.nan_to_num(score_per_slice/num_per_slice)[:-1,:].T
# Out:
# /tmp/ipykernel_368/4122245097.py:1: RuntimeWarning: invalid value encountered in divide
#   scores = np.nan_to_num(score_per_slice/num_per_slice)[:-1,:].T

# %%
plt.figure(figsize=(15,5))
x = np.arange(10)-5
c = [(1, 0, 0, 0.8), (0, 1, 0, 0.8), (0, 0, 1, 0.8)]
l = ['RV', 'MYO', 'LV']
for i in range(3):
    y = scores[i, :]
    plt.bar(x-0.3+0.2*i, y, width=0.2, color=c[i], label=l[i])
plt.bar(x+0.3, scores.mean(axis=0), width=0.2, color='dimgray', label='Average')
plt.xlabel('Index of slices (centered at index=5)')
plt.ylabel('Dice Score')
plt.ylim(0.5, 1)
plt.xticks(x)
plt.legend()
# plt.savefig('images/score_per_slice.png')
